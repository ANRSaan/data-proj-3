# %% [markdown]
# # DataFrame Filtering & GroupBy

# %% [markdown]
# ## Instructions

# %% [markdown]
# In this exercise you will be practicing dataframe filtering skills. Using the 'video_games_sales.csv' file, you will complete the following tasks:
#
# 1. Load the csv into a dataframe.
#
#
#
# 2. Create a new dataframe containing only video games sold for ONE platform of your choice (ex. N64, PS4, etc). Further manipulate the dataframe so you end up with the following columns: platform, release year, genre, and total north american sales for each year in each genre. You will need to use various pandas functions in the process.
#
#
# 3. Pick 5 genres you want to visualize. Create a lineplot with lines showing the trend of total north american sales in each genre over time.

# %% [markdown]
# ### Example DataFrame:

# %% [markdown]
# ![ps4_filtered_df.png](attachment:ps4_filtered_df.png)

# %% [markdown]
# ### Example Lineplot:

# %% [markdown]
# ![example_ps4_lineplot.png](attachment:example_ps4_lineplot.png)
